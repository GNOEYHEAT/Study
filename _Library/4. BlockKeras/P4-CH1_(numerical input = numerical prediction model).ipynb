# %% [markdown]
# * Data Set

# %%
import numpy as np

# 데이터셋 생성
x_train = np.random.random((1000, 1))
y_train = x_train * 2 + np.random.random((1000, 1)) / 3.0
x_test = np.random.random((100, 1))
y_test = x_test * 2 + np.random.random((100, 1)) / 3.0

# 데이터셋 확인
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(x_train, y_train, 'ro')
plt.plot(x_test, y_test, 'bo')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ### 선형회귀 모델

# %%
# 0. 사용할 패키지 불러오기
import numpy as np
from sklearn.metrics import mean_squared_error
import random

# 1. 데이터셋 생성하기
x_train = np.random.random((1000, 1))
y_train = x_train * 2 + np.random.random((1000, 1)) / 3.0
x_test = np.random.random((100, 1))
y_test = x_test * 2 + np.random.random((100, 1)) / 3.0

x_train = x_train.reshape(1000,)
y_train = y_train.reshape(1000,)
x_test = x_test.reshape(100,)
y_test = y_test.reshape(100,)

# 2. 모델 구성하기
w = np.cov(x_train, y_train, bias=1)[0,1] / np.var(x_train)
b = np.average(y_train) - w * np.average(x_train)
print(w, b)

# 3. 모델 평가하기
y_predict = w * x_test + b
mse = mean_squared_error(y_test, y_predict)
print('mse : ' + str(mse))
# Out:
# 1.9940533989966749 0.16829758497619385
# mse : 0.008392029694265694

# %% [markdown]
# ### 퍼셉트론 신경망 모델

# %%
# 0. 사용할 패키지 불러오기
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
import random

# 1. 데이터셋 생성하기
x_train = np.random.random((1000, 1))
y_train = x_train * 2 + np.random.random((1000, 1)) / 3.0
x_test = np.random.random((100, 1))
y_test = x_test * 2 + np.random.random((100, 1)) / 3.0

# 2. 모델 구성하기
model = Sequential()
model.add(Dense(1, input_dim=1))

# 3. 모델 학습과정 설정하기
model.compile(optimizer='rmsprop', loss='mse')

# 4. 모델 학습시키기
hist = model.fit(x_train, y_train, epochs=50, batch_size=64)
w, b = model.get_weights()
print(w,b)

# 5. 학습과정 살펴보기
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(hist.history['loss'])
plt.ylim(0.0, 1.5)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# 6. 모델 평가하기
loss = model.evaluate(x_test, y_test, batch_size=32)
print('loss : ' + str(loss))
# Out:
# Using TensorFlow backend.
# Epoch 1/50
# 1000/1000 [==============================] - 4s 4ms/step - loss: 1.1665
# Epoch 2/50
# 1000/1000 [==============================] - 0s 29us/step - loss: 1.1086
# Epoch 3/50
# 1000/1000 [==============================] - 0s 27us/step - loss: 1.0593
# Epoch 4/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 1.0128
# Epoch 5/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.9673
# Epoch 6/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.9231
# Epoch 7/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.8800
# Epoch 8/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.8382
# Epoch 9/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.7973
# Epoch 10/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.7577
# Epoch 11/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.7194
# Epoch 12/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6825
# Epoch 13/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.6462
# Epoch 14/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.6114
# Epoch 15/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.5778
# Epoch 16/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.5449
# Epoch 17/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.5137
# Epoch 18/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.4830
# Epoch 19/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.4537
# Epoch 20/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.4259
# Epoch 21/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.3989
# Epoch 22/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.3731
# Epoch 23/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.3486
# Epoch 24/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.3253
# Epoch 25/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.3029
# Epoch 26/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.2816
# Epoch 27/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.2615
# Epoch 28/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.2426
# Epoch 29/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.2249
# Epoch 30/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.2082
# Epoch 31/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.1927
# Epoch 32/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.1785
# Epoch 33/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.1655
# Epoch 34/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.1534
# Epoch 35/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.1422
# Epoch 36/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.1320
# Epoch 37/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.1231
# Epoch 38/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.1150
# Epoch 39/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.1081
# Epoch 40/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.1024
# Epoch 41/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.0976
# Epoch 42/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.0936
# Epoch 43/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.0903
# Epoch 44/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.0876
# Epoch 45/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.0850
# Epoch 46/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.0827
# Epoch 47/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.0803
# Epoch 48/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.0781
# Epoch 49/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.0759
# Epoch 50/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.0737
# [[1.1143337]] [0.6215604]
# 100/100 [==============================] - 0s 169us/step
# loss : 0.07442040517926216

# %% [markdown]
# ### 다층퍼셉트론 신경망 모델

# %%
# 0. 사용할 패키지 불러오기
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
import random

# 1. 데이터셋 생성하기 
x_train = np.random.random((1000, 1))
y_train = x_train * 2 + np.random.random((1000, 1)) / 3.0
x_test = np.random.random((100, 1))
y_test = x_test * 2 + np.random.random((100, 1)) / 3.0

# 2. 모델 구성하기
model = Sequential()
model.add(Dense(64, input_dim=1, activation = 'relu'))
model.add(Dense(1))

# 3. 모델 학습과정 설정하기
model.compile(optimizer='rmsprop', loss='mse')

# 4. 모델 학습시키기
hist = model.fit(x_train, y_train, epochs=50, batch_size=64)

# 5. 학습과정 살펴보기
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(hist.history['loss'])
plt.ylim(0.0, 1.5)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# 6. 모델 평가하기
loss = model.evaluate(x_test, y_test, batch_size=32)
print('loss : ' + str(loss))
# Out:
# Epoch 1/50
# 1000/1000 [==============================] - 0s 178us/step - loss: 1.4564
# Epoch 2/50
# 1000/1000 [==============================] - 0s 29us/step - loss: 1.0082
# Epoch 3/50
# 1000/1000 [==============================] - 0s 29us/step - loss: 0.6991
# Epoch 4/50
# 1000/1000 [==============================] - 0s 28us/step - loss: 0.4588
# Epoch 5/50
# 1000/1000 [==============================] - 0s 28us/step - loss: 0.2772
# Epoch 6/50
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.1576
# Epoch 7/50
# 1000/1000 [==============================] - 0s 28us/step - loss: 0.0910
# Epoch 8/50
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.0641
# Epoch 9/50
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.0531
# Epoch 10/50
# 1000/1000 [==============================] - 0s 28us/step - loss: 0.0420
# Epoch 11/50
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.0312
# Epoch 12/50
# 1000/1000 [==============================] - 0s 29us/step - loss: 0.0227
# Epoch 13/50
# 1000/1000 [==============================] - 0s 28us/step - loss: 0.0165
# Epoch 14/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.0125
# Epoch 15/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.0104
# Epoch 16/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.0098
# Epoch 17/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.0095
# Epoch 18/50
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.0094
# Epoch 19/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.0094
# Epoch 20/50
# 1000/1000 [==============================] - 0s 28us/step - loss: 0.0095
# Epoch 21/50
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.0093
# Epoch 22/50
# 1000/1000 [==============================] - 0s 29us/step - loss: 0.0094
# Epoch 23/50
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.0093
# Epoch 24/50
# 1000/1000 [==============================] - 0s 28us/step - loss: 0.0093
# Epoch 25/50
# 1000/1000 [==============================] - 0s 29us/step - loss: 0.0094
# Epoch 26/50
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.0095
# Epoch 27/50
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.0094
# Epoch 28/50
# 1000/1000 [==============================] - 0s 28us/step - loss: 0.0094
# Epoch 29/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.0094
# Epoch 30/50
# 1000/1000 [==============================] - 0s 28us/step - loss: 0.0094
# Epoch 31/50
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.0094
# Epoch 32/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.0094
# Epoch 33/50
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.0095
# Epoch 34/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.0094
# Epoch 35/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.0094
# Epoch 36/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.0094
# Epoch 37/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.0094
# Epoch 38/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.0094
# Epoch 39/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.0095
# Epoch 40/50
# 1000/1000 [==============================] - 0s 29us/step - loss: 0.0094
# Epoch 41/50
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.0095
# Epoch 42/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.0094
# Epoch 43/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.0095
# Epoch 44/50
# 1000/1000 [==============================] - 0s 28us/step - loss: 0.0094
# Epoch 45/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.0094
# Epoch 46/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.0094
# Epoch 47/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.0094
# Epoch 48/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.0095
# Epoch 49/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.0095
# Epoch 50/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.0094
# 100/100 [==============================] - 0s 219us/step
# loss : 0.009542678482830524

# %% [markdown]
# ### 깊은 다층퍼셉트론 신경망 모델

# %%
# 0. 사용할 패키지 불러오기
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
import random

# 1. 데이터셋 생성하기 
x_train = np.random.random((1000, 1))
y_train = x_train * 2 + np.random.random((1000, 1)) / 3.0
x_test = np.random.random((100, 1))
y_test = x_test * 2 + np.random.random((100, 1)) / 3.0

# 2. 모델 구성하기
model = Sequential()
model.add(Dense(64, input_dim=1, activation = 'relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(1))

# 3. 모델 학습과정 설정하기
model.compile(optimizer='rmsprop', loss='mse')

# 4. 모델 학습시키기
hist = model.fit(x_train, y_train, epochs=50, batch_size=64)

# 5. 학습과정 살펴보기
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(hist.history['loss'])
plt.ylim(0.0, 1.5)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# 6. 모델 평가하기
loss = model.evaluate(x_test, y_test, batch_size=32)
print('loss : ' + str(loss))
# Out:
# Epoch 1/50
# 1000/1000 [==============================] - 0s 171us/step - loss: 1.0508
# Epoch 2/50
# 1000/1000 [==============================] - 0s 31us/step - loss: 0.2552
# Epoch 3/50
# 1000/1000 [==============================] - 0s 32us/step - loss: 0.0495
# Epoch 4/50
# 1000/1000 [==============================] - 0s 32us/step - loss: 0.0289
# Epoch 5/50
# 1000/1000 [==============================] - 0s 31us/step - loss: 0.0184
# Epoch 6/50
# 1000/1000 [==============================] - 0s 31us/step - loss: 0.0117
# Epoch 7/50
# 1000/1000 [==============================] - 0s 31us/step - loss: 0.0102
# Epoch 8/50
# 1000/1000 [==============================] - 0s 31us/step - loss: 0.0097
# Epoch 9/50
# 1000/1000 [==============================] - 0s 32us/step - loss: 0.0099
# Epoch 10/50
# 1000/1000 [==============================] - 0s 31us/step - loss: 0.0101
# Epoch 11/50
# 1000/1000 [==============================] - 0s 29us/step - loss: 0.0096
# Epoch 12/50
# 1000/1000 [==============================] - 0s 31us/step - loss: 0.0099
# Epoch 13/50
# 1000/1000 [==============================] - 0s 30us/step - loss: 0.0100
# Epoch 14/50
# 1000/1000 [==============================] - 0s 29us/step - loss: 0.0099
# Epoch 15/50
# 1000/1000 [==============================] - 0s 30us/step - loss: 0.0098
